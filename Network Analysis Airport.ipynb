# %%
import pandas as pd 
import numpy as np

data = pd.read_csv('book1.csv')

# %%
data.shape
# Out:
# (100, 16)

# %%
data.T
# Out:
#                     0       1       2       3       4       5       6   \
# year              2013    2013    2013    2013    2013    2013    2013
# month                2       8       2       4       8       6       2
# day                 26      17      13      11       5      30      14
# dep_time          1807    1459    1812    2122    1832    1500    1442
# sched_dep_time    1630    1445    1815    2115    1835    1505    1445
# dep_delay           97      14      -3       7      -3      -5      -3
# arr_time          1956    1801    2055    2339    2145    1751    1833
# sched_arr_time    1837    1747    2125    2353    2155    1650    1747
# arr_delay           79      14     -30     -14     -10      61      46
# carrier             EV      B6      AS      B6      AA      UA      UA
# flight            4411    1171       7      97     269     685     346
# tailnum         N13566  N661JB  N403AS  N656JB  N3EYAA  N424UA  N446UA
# origin             EWR     LGA     EWR     JFK     JFK     LGA     EWR
# dest               MEM     FLL     SEA     DEN     SEA     ORD     MIA
# air_time           144     147     315     221     358     116     200
# distance           946    1076    2402    1626    2422     733    1085
#
#                     7       8       9    ...        90      91      92  \
# year              2013    2013    2013   ...      2013    2013    2013
# month                7       7      12   ...         9       7       2
# day                 25      10      13   ...        12      29      20
# dep_time           752     557    1907   ...      2109    2017    1234
# sched_dep_time     755     600    1915   ...      1910    1929    1240
# dep_delay           -3      -3      -8   ...       119      48      -6
# arr_time          1037     725    2155   ...         9    2236    1556
# sched_arr_time    1057     715    2219   ...      2215    2212    1540
# arr_delay          -20      10     -24   ...       114      24      16
# carrier             DL      MQ      DL   ...        AA      DL      AA
# flight            2395    3267    2159   ...        21    2041    1853
# tailnum         N909DL  N542MQ  N909DE   ...    N335AA  N358NW  N484AA
# origin             LGA     EWR     JFK   ...       JFK     JFK     EWR
# dest               PBI     ORD     MCO   ...       LAX     ATL     DFW
# air_time           140     113     138   ...       322      97     227
# distance          1035     719     944   ...      2475     760    1372
#
#                     93      94      95      96      97      98      99
# year              2013    2013    2013    2013    2013    2013    2013
# month                6       1      11       3      11       3       5
# day                 20      23      29      10      25       5      21
# dep_time           950    2001    1129    1029    1724     930     626
# sched_dep_time     950    2005    1135    1029    1725     929     630
# dep_delay            0      -4      -6       0      -1       1      -4
# arr_time          1202    2248    1414    1300    1828    1421     858
# sched_arr_time    1205    2258    1436    1344    1845    1426     918
# arr_delay           -3     -10     -22     -44     -17      -5     -20
# carrier             MQ      UA      DL      UA      AA      B6      UA
# flight            3644     405    1875    1605     256     215     490
# tailnum         N534MQ  N402UA  N342NB  N37465  N3CTAA  N638JB  N447UA
# origin             LGA     EWR     LGA     EWR     JFK     EWR     LGA
# dest               ATL     MCO     TPA     LAX     BOS     SJU     IAH
# air_time           106     136     147     308      40     200     189
# distance           762     937    1010    2454     187    1608    1416
#
# [16 rows x 100 columns]

# %%
# converting sched_dep_time to 'std' - Scheduled time of departure
data['std'] = data.sched_dep_time.astype(str).str.replace('(\d{2}$)', '') + ':' + data.sched_dep_time.astype(str).str.extract('(\d{2}$)', expand=False) + ':00'

# %%
data.T
# Out:
#                       0         1         2         3         4         5   \
# year                2013      2013      2013      2013      2013      2013
# month                  2         8         2         4         8         6
# day                   26        17        13        11         5        30
# dep_time            1807      1459      1812      2122      1832      1500
# sched_dep_time      1630      1445      1815      2115      1835      1505
# dep_delay             97        14        -3         7        -3        -5
# arr_time            1956      1801      2055      2339      2145      1751
# sched_arr_time      1837      1747      2125      2353      2155      1650
# arr_delay             79        14       -30       -14       -10        61
# carrier               EV        B6        AS        B6        AA        UA
# flight              4411      1171         7        97       269       685
# tailnum           N13566    N661JB    N403AS    N656JB    N3EYAA    N424UA
# origin               EWR       LGA       EWR       JFK       JFK       LGA
# dest                 MEM       FLL       SEA       DEN       SEA       ORD
# air_time             144       147       315       221       358       116
# distance             946      1076      2402      1626      2422       733
# std             16:30:00  14:45:00  18:15:00  21:15:00  18:35:00  15:05:00
#
#                       6        7        8         9    ...           90  \
# year                2013     2013     2013      2013   ...         2013
# month                  2        7        7        12   ...            9
# day                   14       25       10        13   ...           12
# dep_time            1442      752      557      1907   ...         2109
# sched_dep_time      1445      755      600      1915   ...         1910
# dep_delay             -3       -3       -3        -8   ...          119
# arr_time            1833     1037      725      2155   ...            9
# sched_arr_time      1747     1057      715      2219   ...         2215
# arr_delay             46      -20       10       -24   ...          114
# carrier               UA       DL       MQ        DL   ...           AA
# flight               346     2395     3267      2159   ...           21
# tailnum           N446UA   N909DL   N542MQ    N909DE   ...       N335AA
# origin               EWR      LGA      EWR       JFK   ...          JFK
# dest                 MIA      PBI      ORD       MCO   ...          LAX
# air_time             200      140      113       138   ...          322
# distance            1085     1035      719       944   ...         2475
# std             14:45:00  7:55:00  6:00:00  19:15:00   ...     19:10:00
#
#                       91        92       93        94        95        96  \
# year                2013      2013     2013      2013      2013      2013
# month                  7         2        6         1        11         3
# day                   29        20       20        23        29        10
# dep_time            2017      1234      950      2001      1129      1029
# sched_dep_time      1929      1240      950      2005      1135      1029
# dep_delay             48        -6        0        -4        -6         0
# arr_time            2236      1556     1202      2248      1414      1300
# sched_arr_time      2212      1540     1205      2258      1436      1344
# arr_delay             24        16       -3       -10       -22       -44
# carrier               DL        AA       MQ        UA        DL        UA
# flight              2041      1853     3644       405      1875      1605
# tailnum           N358NW    N484AA   N534MQ    N402UA    N342NB    N37465
# origin               JFK       EWR      LGA       EWR       LGA       EWR
# dest                 ATL       DFW      ATL       MCO       TPA       LAX
# air_time              97       227      106       136       147       308
# distance             760      1372      762       937      1010      2454
# std             19:29:00  12:40:00  9:50:00  20:05:00  11:35:00  10:29:00
#
#                       97       98       99
# year                2013     2013     2013
# month                 11        3        5
# day                   25        5       21
# dep_time            1724      930      626
# sched_dep_time      1725      929      630
# dep_delay             -1        1       -4
# arr_time            1828     1421      858
# sched_arr_time      1845     1426      918
# arr_delay            -17       -5      -20
# carrier               AA       B6       UA
# flight               256      215      490
# tailnum           N3CTAA   N638JB   N447UA
# origin               JFK      EWR      LGA
# dest                 BOS      SJU      IAH
# air_time              40      200      189
# distance             187     1608     1416
# std             17:25:00  9:29:00  6:30:00
#
# [17 rows x 100 columns]

# %%
# converting sched_arr_time to 'sta' - Scheduled time of arrival
data['sta'] = data.sched_arr_time.astype(str).str.replace('(\d{2}$)', '') + ':' + data.sched_arr_time.astype(str).str.extract('(\d{2}$)', expand=False) + ':00'

# converting dep_time to 'atd' - Actual time of departure
data['atd'] = data.dep_time.fillna(0).astype(np.int64).astype(str).str.replace('(\d{2}$)', '') + ':' + data.dep_time.fillna(0).astype(np.int64).astype(str).str.extract('(\d{2}$)', expand=False) + ':00'

# %%
# converting arr_time to 'ata' - Actual time of arrival
data['ata'] = data.arr_time.fillna(0).astype(np.int64).astype(str).str.replace('(\d{2}$)', '') + ':' + data.arr_time.fillna(0).astype(np.int64).astype(str).str.extract('(\d{2}$)', expand=False) + ':00'

# %%
data.T
# Out:
#                       0         1         2         3         4         5   \
# year                2013      2013      2013      2013      2013      2013
# month                  2         8         2         4         8         6
# day                   26        17        13        11         5        30
# dep_time            1807      1459      1812      2122      1832      1500
# sched_dep_time      1630      1445      1815      2115      1835      1505
# dep_delay             97        14        -3         7        -3        -5
# arr_time            1956      1801      2055      2339      2145      1751
# sched_arr_time      1837      1747      2125      2353      2155      1650
# arr_delay             79        14       -30       -14       -10        61
# carrier               EV        B6        AS        B6        AA        UA
# flight              4411      1171         7        97       269       685
# tailnum           N13566    N661JB    N403AS    N656JB    N3EYAA    N424UA
# origin               EWR       LGA       EWR       JFK       JFK       LGA
# dest                 MEM       FLL       SEA       DEN       SEA       ORD
# air_time             144       147       315       221       358       116
# distance             946      1076      2402      1626      2422       733
# std             16:30:00  14:45:00  18:15:00  21:15:00  18:35:00  15:05:00
# sta             18:37:00  17:47:00  21:25:00  23:53:00  21:55:00  16:50:00
# atd             18:07:00  14:59:00  18:12:00  21:22:00  18:32:00  15:00:00
# ata             19:56:00  18:01:00  20:55:00  23:39:00  21:45:00  17:51:00
#
#                       6         7        8         9    ...           90  \
# year                2013      2013     2013      2013   ...         2013
# month                  2         7        7        12   ...            9
# day                   14        25       10        13   ...           12
# dep_time            1442       752      557      1907   ...         2109
# sched_dep_time      1445       755      600      1915   ...         1910
# dep_delay             -3        -3       -3        -8   ...          119
# arr_time            1833      1037      725      2155   ...            9
# sched_arr_time      1747      1057      715      2219   ...         2215
# arr_delay             46       -20       10       -24   ...          114
# carrier               UA        DL       MQ        DL   ...           AA
# flight               346      2395     3267      2159   ...           21
# tailnum           N446UA    N909DL   N542MQ    N909DE   ...       N335AA
# origin               EWR       LGA      EWR       JFK   ...          JFK
# dest                 MIA       PBI      ORD       MCO   ...          LAX
# air_time             200       140      113       138   ...          322
# distance            1085      1035      719       944   ...         2475
# std             14:45:00   7:55:00  6:00:00  19:15:00   ...     19:10:00
# sta             17:47:00  10:57:00  7:15:00  22:19:00   ...     22:15:00
# atd             14:42:00   7:52:00  5:57:00  19:07:00   ...     21:09:00
# ata             18:33:00  10:37:00  7:25:00  21:55:00   ...          NaN
#
#                       91        92        93        94        95        96  \
# year                2013      2013      2013      2013      2013      2013
# month                  7         2         6         1        11         3
# day                   29        20        20        23        29        10
# dep_time            2017      1234       950      2001      1129      1029
# sched_dep_time      1929      1240       950      2005      1135      1029
# dep_delay             48        -6         0        -4        -6         0
# arr_time            2236      1556      1202      2248      1414      1300
# sched_arr_time      2212      1540      1205      2258      1436      1344
# arr_delay             24        16        -3       -10       -22       -44
# carrier               DL        AA        MQ        UA        DL        UA
# flight              2041      1853      3644       405      1875      1605
# tailnum           N358NW    N484AA    N534MQ    N402UA    N342NB    N37465
# origin               JFK       EWR       LGA       EWR       LGA       EWR
# dest                 ATL       DFW       ATL       MCO       TPA       LAX
# air_time              97       227       106       136       147       308
# distance             760      1372       762       937      1010      2454
# std             19:29:00  12:40:00   9:50:00  20:05:00  11:35:00  10:29:00
# sta             22:12:00  15:40:00  12:05:00  22:58:00  14:36:00  13:44:00
# atd             20:17:00  12:34:00   9:50:00  20:01:00  11:29:00  10:29:00
# ata             22:36:00  15:56:00  12:02:00  22:48:00  14:14:00  13:00:00
#
#                       97        98       99
# year                2013      2013     2013
# month                 11         3        5
# day                   25         5       21
# dep_time            1724       930      626
# sched_dep_time      1725       929      630
# dep_delay             -1         1       -4
# arr_time            1828      1421      858
# sched_arr_time      1845      1426      918
# arr_delay            -17        -5      -20
# carrier               AA        B6       UA
# flight               256       215      490
# tailnum           N3CTAA    N638JB   N447UA
# origin               JFK       EWR      LGA
# dest                 BOS       SJU      IAH
# air_time              40       200      189
# distance             187      1608     1416
# std             17:25:00   9:29:00  6:30:00
# sta             18:45:00  14:26:00  9:18:00
# atd             17:24:00   9:30:00  6:26:00
# ata             18:28:00  14:21:00  8:58:00
#
# [20 rows x 100 columns]

# %%
data['date'] = pd.to_datetime(data[['year', 'month', 'day']])

# %%
data.T
# Out:
#                                  0                    1                    2   \
# year                           2013                 2013                 2013
# month                             2                    8                    2
# day                              26                   17                   13
# dep_time                       1807                 1459                 1812
# sched_dep_time                 1630                 1445                 1815
# dep_delay                        97                   14                   -3
# arr_time                       1956                 1801                 2055
# sched_arr_time                 1837                 1747                 2125
# arr_delay                        79                   14                  -30
# carrier                          EV                   B6                   AS
# flight                         4411                 1171                    7
# tailnum                      N13566               N661JB               N403AS
# origin                          EWR                  LGA                  EWR
# dest                            MEM                  FLL                  SEA
# air_time                        144                  147                  315
# distance                        946                 1076                 2402
# std                        16:30:00             14:45:00             18:15:00
# sta                        18:37:00             17:47:00             21:25:00
# atd                        18:07:00             14:59:00             18:12:00
# ata                        19:56:00             18:01:00             20:55:00
# date            2013-02-26 00:00:00  2013-08-17 00:00:00  2013-02-13 00:00:00
#
#                                  3                    4                    5   \
# year                           2013                 2013                 2013
# month                             4                    8                    6
# day                              11                    5                   30
# dep_time                       2122                 1832                 1500
# sched_dep_time                 2115                 1835                 1505
# dep_delay                         7                   -3                   -5
# arr_time                       2339                 2145                 1751
# sched_arr_time                 2353                 2155                 1650
# arr_delay                       -14                  -10                   61
# carrier                          B6                   AA                   UA
# flight                           97                  269                  685
# tailnum                      N656JB               N3EYAA               N424UA
# origin                          JFK                  JFK                  LGA
# dest                            DEN                  SEA                  ORD
# air_time                        221                  358                  116
# distance                       1626                 2422                  733
# std                        21:15:00             18:35:00             15:05:00
# sta                        23:53:00             21:55:00             16:50:00
# atd                        21:22:00             18:32:00             15:00:00
# ata                        23:39:00             21:45:00             17:51:00
# date            2013-04-11 00:00:00  2013-08-05 00:00:00  2013-06-30 00:00:00
#
#                                  6                    7                    8   \
# year                           2013                 2013                 2013
# month                             2                    7                    7
# day                              14                   25                   10
# dep_time                       1442                  752                  557
# sched_dep_time                 1445                  755                  600
# dep_delay                        -3                   -3                   -3
# arr_time                       1833                 1037                  725
# sched_arr_time                 1747                 1057                  715
# arr_delay                        46                  -20                   10
# carrier                          UA                   DL                   MQ
# flight                          346                 2395                 3267
# tailnum                      N446UA               N909DL               N542MQ
# origin                          EWR                  LGA                  EWR
# dest                            MIA                  PBI                  ORD
# air_time                        200                  140                  113
# distance                       1085                 1035                  719
# std                        14:45:00              7:55:00              6:00:00
# sta                        17:47:00             10:57:00              7:15:00
# atd                        14:42:00              7:52:00              5:57:00
# ata                        18:33:00             10:37:00              7:25:00
# date            2013-02-14 00:00:00  2013-07-25 00:00:00  2013-07-10 00:00:00
#
#                                  9          ...                            90  \
# year                           2013         ...                          2013
# month                            12         ...                             9
# day                              13         ...                            12
# dep_time                       1907         ...                          2109
# sched_dep_time                 1915         ...                          1910
# dep_delay                        -8         ...                           119
# arr_time                       2155         ...                             9
# sched_arr_time                 2219         ...                          2215
# arr_delay                       -24         ...                           114
# carrier                          DL         ...                            AA
# flight                         2159         ...                            21
# tailnum                      N909DE         ...                        N335AA
# origin                          JFK         ...                           JFK
# dest                            MCO         ...                           LAX
# air_time                        138         ...                           322
# distance                        944         ...                          2475
# std                        19:15:00         ...                      19:10:00
# sta                        22:19:00         ...                      22:15:00
# atd                        19:07:00         ...                      21:09:00
# ata                        21:55:00         ...                           NaN
# date            2013-12-13 00:00:00         ...           2013-09-12 00:00:00
#
#                                  91                   92                   93  \
# year                           2013                 2013                 2013
# month                             7                    2                    6
# day                              29                   20                   20
# dep_time                       2017                 1234                  950
# sched_dep_time                 1929                 1240                  950
# dep_delay                        48                   -6                    0
# arr_time                       2236                 1556                 1202
# sched_arr_time                 2212                 1540                 1205
# arr_delay                        24                   16                   -3
# carrier                          DL                   AA                   MQ
# flight                         2041                 1853                 3644
# tailnum                      N358NW               N484AA               N534MQ
# origin                          JFK                  EWR                  LGA
# dest                            ATL                  DFW                  ATL
# air_time                         97                  227                  106
# distance                        760                 1372                  762
# std                        19:29:00             12:40:00              9:50:00
# sta                        22:12:00             15:40:00             12:05:00
# atd                        20:17:00             12:34:00              9:50:00
# ata                        22:36:00             15:56:00             12:02:00
# date            2013-07-29 00:00:00  2013-02-20 00:00:00  2013-06-20 00:00:00
#
#                                  94                   95                   96  \
# year                           2013                 2013                 2013
# month                             1                   11                    3
# day                              23                   29                   10
# dep_time                       2001                 1129                 1029
# sched_dep_time                 2005                 1135                 1029
# dep_delay                        -4                   -6                    0
# arr_time                       2248                 1414                 1300
# sched_arr_time                 2258                 1436                 1344
# arr_delay                       -10                  -22                  -44
# carrier                          UA                   DL                   UA
# flight                          405                 1875                 1605
# tailnum                      N402UA               N342NB               N37465
# origin                          EWR                  LGA                  EWR
# dest                            MCO                  TPA                  LAX
# air_time                        136                  147                  308
# distance                        937                 1010                 2454
# std                        20:05:00             11:35:00             10:29:00
# sta                        22:58:00             14:36:00             13:44:00
# atd                        20:01:00             11:29:00             10:29:00
# ata                        22:48:00             14:14:00             13:00:00
# date            2013-01-23 00:00:00  2013-11-29 00:00:00  2013-03-10 00:00:00
#
#                                  97                   98                   99
# year                           2013                 2013                 2013
# month                            11                    3                    5
# day                              25                    5                   21
# dep_time                       1724                  930                  626
# sched_dep_time                 1725                  929                  630
# dep_delay                        -1                    1                   -4
# arr_time                       1828                 1421                  858
# sched_arr_time                 1845                 1426                  918
# arr_delay                       -17                   -5                  -20
# carrier                          AA                   B6                   UA
# flight                          256                  215                  490
# tailnum                      N3CTAA               N638JB               N447UA
# origin                          JFK                  EWR                  LGA
# dest                            BOS                  SJU                  IAH
# air_time                         40                  200                  189
# distance                        187                 1608                 1416
# std                        17:25:00              9:29:00              6:30:00
# sta                        18:45:00             14:26:00              9:18:00
# atd                        17:24:00              9:30:00              6:26:00
# ata                        18:28:00             14:21:00              8:58:00
# date            2013-11-25 00:00:00  2013-03-05 00:00:00  2013-05-21 00:00:00
#
# [21 rows x 100 columns]

# %%
# finally we drop the columns we don't need
data = data.drop(columns = ['year', 'month', 'day'])

# %%
import networkx as nx
FG = nx.from_pandas_edgelist(data, source='origin', target='dest', edge_attr=True,)

# %%
FG.nodes()
# Out:
# NodeView(('EWR', 'MEM', 'LGA', 'FLL', 'SEA', 'JFK', 'DEN', 'ORD', 'MIA', 'PBI', 'MCO', 'CMH', 'MSP', 'IAD', 'CLT', 'TPA', 'DCA', 'SJU', 'ATL', 'BHM', 'SRQ', 'MSY', 'DTW', 'LAX', 'JAX', 'RDU', 'MDW', 'DFW', 'IAH', 'SFO', 'STL', 'CVG', 'IND', 'RSW', 'BOS', 'CLE'))

# %%
FG.edges()
# Out:
# EdgeView([('EWR', 'MEM'), ('EWR', 'SEA'), ('EWR', 'MIA'), ('EWR', 'ORD'), ('EWR', 'MSP'), ('EWR', 'TPA'), ('EWR', 'MSY'), ('EWR', 'DFW'), ('EWR', 'IAH'), ('EWR', 'SFO'), ('EWR', 'CVG'), ('EWR', 'IND'), ('EWR', 'RDU'), ('EWR', 'IAD'), ('EWR', 'RSW'), ('EWR', 'BOS'), ('EWR', 'PBI'), ('EWR', 'LAX'), ('EWR', 'MCO'), ('EWR', 'SJU'), ('LGA', 'FLL'), ('LGA', 'ORD'), ('LGA', 'PBI'), ('LGA', 'CMH'), ('LGA', 'IAD'), ('LGA', 'CLT'), ('LGA', 'MIA'), ('LGA', 'DCA'), ('LGA', 'BHM'), ('LGA', 'RDU'), ('LGA', 'ATL'), ('LGA', 'TPA'), ('LGA', 'MDW'), ('LGA', 'DEN'), ('LGA', 'MSP'), ('LGA', 'DTW'), ('LGA', 'STL'), ('LGA', 'MCO'), ('LGA', 'CVG'), ('LGA', 'IAH'), ('FLL', 'JFK'), ('SEA', 'JFK'), ('JFK', 'DEN'), ('JFK', 'MCO'), ('JFK', 'TPA'), ('JFK', 'SJU'), ('JFK', 'ATL'), ('JFK', 'SRQ'), ('JFK', 'DCA'), ('JFK', 'DTW'), ('JFK', 'LAX'), ('JFK', 'JAX'), ('JFK', 'CLT'), ('JFK', 'PBI'), ('JFK', 'CLE'), ('JFK', 'IAD'), ('JFK', 'BOS')])

# %%
nx.draw_networkx(FG, with_labels=True)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
nx.draw(FG)

# %%
nx.algorithms.degree_centrality(FG) # Notice the 3 airports from which all of our 100 rows of data originates
# Out:
# {'EWR': 0.5714285714285714,
#  'MEM': 0.02857142857142857,
#  'LGA': 0.5714285714285714,
#  'FLL': 0.05714285714285714,
#  'SEA': 0.05714285714285714,
#  'JFK': 0.4857142857142857,
#  'DEN': 0.05714285714285714,
#  'ORD': 0.05714285714285714,
#  'MIA': 0.05714285714285714,
#  'PBI': 0.08571428571428572,
#  'MCO': 0.08571428571428572,
#  'CMH': 0.02857142857142857,
#  'MSP': 0.05714285714285714,
#  'IAD': 0.08571428571428572,
#  'CLT': 0.05714285714285714,
#  'TPA': 0.08571428571428572,
#  'DCA': 0.05714285714285714,
#  'SJU': 0.05714285714285714,
#  'ATL': 0.05714285714285714,
#  'BHM': 0.02857142857142857,
#  'SRQ': 0.02857142857142857,
#  'MSY': 0.02857142857142857,
#  'DTW': 0.05714285714285714,
#  'LAX': 0.05714285714285714,
#  'JAX': 0.02857142857142857,
#  'RDU': 0.05714285714285714,
#  'MDW': 0.02857142857142857,
#  'DFW': 0.02857142857142857,
#  'IAH': 0.05714285714285714,
#  'SFO': 0.02857142857142857,
#  'STL': 0.02857142857142857,
#  'CVG': 0.05714285714285714,
#  'IND': 0.02857142857142857,
#  'RSW': 0.02857142857142857,
#  'BOS': 0.05714285714285714,
#  'CLE': 0.02857142857142857}

# %%
nx.density(FG) # Average edge density of the Graphs
# Out:
# 0.09047619047619047

# %%
nx.average_shortest_path_length(FG) # Average shortest path length for ALL paths in the Graph
# Out:
# 2.36984126984127

# %%
nx.average_degree_connectivity(FG) # For a node of degree k - What is the average of its neighbours' degree?
# Out:
# {20: 1.95, 1: 19.307692307692307, 2: 19.0625, 17: 2.0588235294117645, 3: 19.0}

# %%
# Let us find all the paths available
for path in nx.all_simple_paths(FG, source='JAX', target='DFW'):
 print(path)
# Out:
# ['JAX', 'JFK', 'DEN', 'LGA', 'ORD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DEN', 'LGA', 'PBI', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DEN', 'LGA', 'IAD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DEN', 'LGA', 'MIA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DEN', 'LGA', 'RDU', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DEN', 'LGA', 'TPA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DEN', 'LGA', 'MSP', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DEN', 'LGA', 'MCO', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DEN', 'LGA', 'CVG', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DEN', 'LGA', 'IAH', 'EWR', 'DFW']
# ['JAX', 'JFK', 'SEA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'MCO', 'LGA', 'ORD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'MCO', 'LGA', 'PBI', 'EWR', 'DFW']
# ['JAX', 'JFK', 'MCO', 'LGA', 'IAD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'MCO', 'LGA', 'MIA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'MCO', 'LGA', 'RDU', 'EWR', 'DFW']
# ['JAX', 'JFK', 'MCO', 'LGA', 'TPA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'MCO', 'LGA', 'MSP', 'EWR', 'DFW']
# ['JAX', 'JFK', 'MCO', 'LGA', 'CVG', 'EWR', 'DFW']
# ['JAX', 'JFK', 'MCO', 'LGA', 'IAH', 'EWR', 'DFW']
# ['JAX', 'JFK', 'MCO', 'EWR', 'DFW']
# ['JAX', 'JFK', 'TPA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'TPA', 'LGA', 'ORD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'TPA', 'LGA', 'PBI', 'EWR', 'DFW']
# ['JAX', 'JFK', 'TPA', 'LGA', 'IAD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'TPA', 'LGA', 'MIA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'TPA', 'LGA', 'RDU', 'EWR', 'DFW']
# ['JAX', 'JFK', 'TPA', 'LGA', 'MSP', 'EWR', 'DFW']
# ['JAX', 'JFK', 'TPA', 'LGA', 'MCO', 'EWR', 'DFW']
# ['JAX', 'JFK', 'TPA', 'LGA', 'CVG', 'EWR', 'DFW']
# ['JAX', 'JFK', 'TPA', 'LGA', 'IAH', 'EWR', 'DFW']
# ['JAX', 'JFK', 'SJU', 'EWR', 'DFW']
# ['JAX', 'JFK', 'ATL', 'LGA', 'ORD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'ATL', 'LGA', 'PBI', 'EWR', 'DFW']
# ['JAX', 'JFK', 'ATL', 'LGA', 'IAD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'ATL', 'LGA', 'MIA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'ATL', 'LGA', 'RDU', 'EWR', 'DFW']
# ['JAX', 'JFK', 'ATL', 'LGA', 'TPA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'ATL', 'LGA', 'MSP', 'EWR', 'DFW']
# ['JAX', 'JFK', 'ATL', 'LGA', 'MCO', 'EWR', 'DFW']
# ['JAX', 'JFK', 'ATL', 'LGA', 'CVG', 'EWR', 'DFW']
# ['JAX', 'JFK', 'ATL', 'LGA', 'IAH', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DCA', 'LGA', 'ORD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DCA', 'LGA', 'PBI', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DCA', 'LGA', 'IAD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DCA', 'LGA', 'MIA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DCA', 'LGA', 'RDU', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DCA', 'LGA', 'TPA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DCA', 'LGA', 'MSP', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DCA', 'LGA', 'MCO', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DCA', 'LGA', 'CVG', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DCA', 'LGA', 'IAH', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DTW', 'LGA', 'ORD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DTW', 'LGA', 'PBI', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DTW', 'LGA', 'IAD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DTW', 'LGA', 'MIA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DTW', 'LGA', 'RDU', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DTW', 'LGA', 'TPA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DTW', 'LGA', 'MSP', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DTW', 'LGA', 'MCO', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DTW', 'LGA', 'CVG', 'EWR', 'DFW']
# ['JAX', 'JFK', 'DTW', 'LGA', 'IAH', 'EWR', 'DFW']
# ['JAX', 'JFK', 'LAX', 'EWR', 'DFW']
# ['JAX', 'JFK', 'FLL', 'LGA', 'ORD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'FLL', 'LGA', 'PBI', 'EWR', 'DFW']
# ['JAX', 'JFK', 'FLL', 'LGA', 'IAD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'FLL', 'LGA', 'MIA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'FLL', 'LGA', 'RDU', 'EWR', 'DFW']
# ['JAX', 'JFK', 'FLL', 'LGA', 'TPA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'FLL', 'LGA', 'MSP', 'EWR', 'DFW']
# ['JAX', 'JFK', 'FLL', 'LGA', 'MCO', 'EWR', 'DFW']
# ['JAX', 'JFK', 'FLL', 'LGA', 'CVG', 'EWR', 'DFW']
# ['JAX', 'JFK', 'FLL', 'LGA', 'IAH', 'EWR', 'DFW']
# ['JAX', 'JFK', 'CLT', 'LGA', 'ORD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'CLT', 'LGA', 'PBI', 'EWR', 'DFW']
# ['JAX', 'JFK', 'CLT', 'LGA', 'IAD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'CLT', 'LGA', 'MIA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'CLT', 'LGA', 'RDU', 'EWR', 'DFW']
# ['JAX', 'JFK', 'CLT', 'LGA', 'TPA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'CLT', 'LGA', 'MSP', 'EWR', 'DFW']
# ['JAX', 'JFK', 'CLT', 'LGA', 'MCO', 'EWR', 'DFW']
# ['JAX', 'JFK', 'CLT', 'LGA', 'CVG', 'EWR', 'DFW']
# ['JAX', 'JFK', 'CLT', 'LGA', 'IAH', 'EWR', 'DFW']
# ['JAX', 'JFK', 'PBI', 'LGA', 'ORD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'PBI', 'LGA', 'IAD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'PBI', 'LGA', 'MIA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'PBI', 'LGA', 'RDU', 'EWR', 'DFW']
# ['JAX', 'JFK', 'PBI', 'LGA', 'TPA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'PBI', 'LGA', 'MSP', 'EWR', 'DFW']
# ['JAX', 'JFK', 'PBI', 'LGA', 'MCO', 'EWR', 'DFW']
# ['JAX', 'JFK', 'PBI', 'LGA', 'CVG', 'EWR', 'DFW']
# ['JAX', 'JFK', 'PBI', 'LGA', 'IAH', 'EWR', 'DFW']
# ['JAX', 'JFK', 'PBI', 'EWR', 'DFW']
# ['JAX', 'JFK', 'IAD', 'LGA', 'ORD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'IAD', 'LGA', 'PBI', 'EWR', 'DFW']
# ['JAX', 'JFK', 'IAD', 'LGA', 'MIA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'IAD', 'LGA', 'RDU', 'EWR', 'DFW']
# ['JAX', 'JFK', 'IAD', 'LGA', 'TPA', 'EWR', 'DFW']
# ['JAX', 'JFK', 'IAD', 'LGA', 'MSP', 'EWR', 'DFW']
# ['JAX', 'JFK', 'IAD', 'LGA', 'MCO', 'EWR', 'DFW']
# ['JAX', 'JFK', 'IAD', 'LGA', 'CVG', 'EWR', 'DFW']
# ['JAX', 'JFK', 'IAD', 'LGA', 'IAH', 'EWR', 'DFW']
# ['JAX', 'JFK', 'IAD', 'EWR', 'DFW']
# ['JAX', 'JFK', 'BOS', 'EWR', 'DFW']

# %%
# Let us find the dijkstra path from JAX to DFW.
# You can read more in-depth on how dijkstra works from this resource - https://courses.csail.mit.edu/6.006/fall11/lectures/lecture16.pdf
dijpath = nx.dijkstra_path(FG, source='JAX', target='DFW')
dijpath
# Out:
# ['JAX', 'JFK', 'SEA', 'EWR', 'DFW']

# %%
# Let us try to find the dijkstra path weighted by airtime (approximate case)
shortpath = nx.dijkstra_path(FG, source='JAX', target='DFW', weight='air_time')
shortpath
# Out:
# ['JAX', 'JFK', 'BOS', 'EWR', 'DFW']

# %%
dc=nx.degree_centrality(FG)

dc
# Out:
# {'EWR': 0.5714285714285714,
#  'MEM': 0.02857142857142857,
#  'LGA': 0.5714285714285714,
#  'FLL': 0.05714285714285714,
#  'SEA': 0.05714285714285714,
#  'JFK': 0.4857142857142857,
#  'DEN': 0.05714285714285714,
#  'ORD': 0.05714285714285714,
#  'MIA': 0.05714285714285714,
#  'PBI': 0.08571428571428572,
#  'MCO': 0.08571428571428572,
#  'CMH': 0.02857142857142857,
#  'MSP': 0.05714285714285714,
#  'IAD': 0.08571428571428572,
#  'CLT': 0.05714285714285714,
#  'TPA': 0.08571428571428572,
#  'DCA': 0.05714285714285714,
#  'SJU': 0.05714285714285714,
#  'ATL': 0.05714285714285714,
#  'BHM': 0.02857142857142857,
#  'SRQ': 0.02857142857142857,
#  'MSY': 0.02857142857142857,
#  'DTW': 0.05714285714285714,
#  'LAX': 0.05714285714285714,
#  'JAX': 0.02857142857142857,
#  'RDU': 0.05714285714285714,
#  'MDW': 0.02857142857142857,
#  'DFW': 0.02857142857142857,
#  'IAH': 0.05714285714285714,
#  'SFO': 0.02857142857142857,
#  'STL': 0.02857142857142857,
#  'CVG': 0.05714285714285714,
#  'IND': 0.02857142857142857,
#  'RSW': 0.02857142857142857,
#  'BOS': 0.05714285714285714,
#  'CLE': 0.02857142857142857}

# %%
nx.betweenness_centrality(FG)
# Out:
# {'EWR': 0.44733893557422966,
#  'MEM': 0.0,
#  'LGA': 0.40952380952380946,
#  'FLL': 0.007282913165266107,
#  'SEA': 0.01204481792717087,
#  'JFK': 0.30952380952380965,
#  'DEN': 0.007282913165266107,
#  'ORD': 0.011484593837535018,
#  'MIA': 0.011484593837535018,
#  'PBI': 0.030812324929971994,
#  'MCO': 0.030812324929971994,
#  'CMH': 0.0,
#  'MSP': 0.011484593837535018,
#  'IAD': 0.030812324929971994,
#  'CLT': 0.007282913165266107,
#  'TPA': 0.030812324929971994,
#  'DCA': 0.007282913165266107,
#  'SJU': 0.01204481792717087,
#  'ATL': 0.007282913165266107,
#  'BHM': 0.0,
#  'SRQ': 0.0,
#  'MSY': 0.0,
#  'DTW': 0.007282913165266107,
#  'LAX': 0.01204481792717087,
#  'JAX': 0.0,
#  'RDU': 0.011484593837535018,
#  'MDW': 0.0,
#  'DFW': 0.0,
#  'IAH': 0.011484593837535018,
#  'SFO': 0.0,
#  'STL': 0.0,
#  'CVG': 0.011484593837535018,
#  'IND': 0.0,
#  'RSW': 0.0,
#  'BOS': 0.01204481792717087,
#  'CLE': 0.0}

# %%
FG.nodes
# Out:
# NodeView(('EWR', 'MEM', 'LGA', 'FLL', 'SEA', 'JFK', 'DEN', 'ORD', 'MIA', 'PBI', 'MCO', 'CMH', 'MSP', 'IAD', 'CLT', 'TPA', 'DCA', 'SJU', 'ATL', 'BHM', 'SRQ', 'MSY', 'DTW', 'LAX', 'JAX', 'RDU', 'MDW', 'DFW', 'IAH', 'SFO', 'STL', 'CVG', 'IND', 'RSW', 'BOS', 'CLE'))

# %%
K=nx.complete_graph(FG)

# %%
nx.draw(K)

# %%
K=nx.path_graph(FG)

# %%
nx.draw(K)
